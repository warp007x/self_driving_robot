# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import RPi.GPIO as GPIO
print(np,'\n', pd,'\n', cv2,'\n', plt)
print(GPIO.VERSION)
# Out:
# <module 'numpy' from '/home/waifupi/dev/openCV/venv/lib/python3.9/site-packages/numpy/__init__.py'>
#  <module 'pandas' from '/home/waifupi/dev/openCV/venv/lib/python3.9/site-packages/pandas/__init__.py'>
#  <module 'cv2' from '/home/waifupi/dev/openCV/venv/lib/python3.9/site-packages/cv2/__init__.py'>
#  <module 'matplotlib.pyplot' from '/home/waifupi/dev/openCV/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>
# 0.7.1

# %%
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
blank = np.zeros((512, 512, 3),np.uint16) 
imshow("black image",blank, 6)
